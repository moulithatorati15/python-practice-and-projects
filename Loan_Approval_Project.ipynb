# %% [markdown]
# # Load Dataset

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %% [markdown]
# # Display Dataset

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Complete Dataset:")
display(df)
# Out:
# Complete Dataset:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Display First 5 Rows

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("First 5 Rows of the Dataset:")
display(df.head())
# Out:
# First 5 Rows of the Dataset:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# ...

# %% [markdown]
# # Display Last 5 Rows

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Last 5 Rows of the Dataset:")
display(df.tail())
# Out:
# Last 5 Rows of the Dataset:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# ...

# %% [markdown]
# # Display Random Sample

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Random Sample of 5 Rows:")
display(df.sample(5, random_state=42))
# Out:
# Random Sample of 5 Rows:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 350  LP002139    Male     Yes          0  Graduate            No
# 377  LP002223    Male     Yes          0  Graduate            No
# 163  LP001570    Male     Yes          2  Graduate            No
# 609  LP002978  Female      No          0  Graduate            No
# 132  LP001478    Male      No          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 350             9083                0.0       228.0             360.0
# 377             4310                0.0       130.0             360.0
# 163             4167             1447.0       158.0             360.0
# 609             2900                0.0        71.0             360.0
# 132             2718                0.0        70.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 350             1.0     Semiurban           Y
# ...

# %% [markdown]
# # Dataset Shape

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Shape of Dataset:")
print(df.shape)
# Out:
# Shape of Dataset:
# (614, 13)

# %% [markdown]
# # Dataset Columns

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Columns of Dataset:")
print(df.columns)
# Out:
# Columns of Dataset:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='str')

# %% [markdown]
# # Dataset Information

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Dataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    str
#  1   Gender             601 non-null    str
#  2   Married            611 non-null    str
#  3   Dependents         599 non-null    str
#  4   Education          614 non-null    str
#  5   Self_Employed      582 non-null    str
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    str
#  12  Loan_Status        614 non-null    str
# dtypes: float64(4), int64(1), str(8)
# memory usage: 83.4 KB
# None

# %% [markdown]
# # Descriptive Statistics

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
print("Descriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # Missing Values

# %%
import pandas as pd
missing_values = df.isnull().sum()

print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# # Duplicate Values

# %%
import pandas as pd
duplicate_count = df.duplicated().sum()

print("Number of Duplicate Rows:", duplicate_count)
# Out:
# Number of Duplicate Rows: 0

# %% [markdown]
# # Unique Values

# %%
import pandas as pd
print("Unique Values in Each Column:\n")
for column in df.columns:
    print(f"\n{column}:")
    print(df[column].unique())

#display how many unique values each column contains:
print("Number of Unique Values in Each Column:\n")

print(df.nunique())
# Out:
# Unique Values in Each Column:
#
#
# Loan_ID:
# <ArrowStringArray>
# ['LP001002', 'LP001003', 'LP001005', 'LP001006', 'LP001008', 'LP001011',
#  'LP001013', 'LP001014', 'LP001018', 'LP001020',
#  ...
#  'LP002959', 'LP002960', 'LP002961', 'LP002964', 'LP002974', 'LP002978',
#  'LP002979', 'LP002983', 'LP002984', 'LP002990']
# Length: 614, dtype: str
#
# Gender:
# <ArrowStringArray>
# ['Male', 'Female', nan]
# Length: 3, dtype: str
#
# Married:
# <ArrowStringArray>
# ['No', 'Yes', nan]
# Length: 3, dtype: str
#
# Dependents:
# <ArrowStringArray>
# ['0', '1', '2', '3+', nan]
# Length: 5, dtype: str
#
# Education:
# <ArrowStringArray>
# ['Graduate', 'Not Graduate']
# Length: 2, dtype: str
#
# Self_Employed:
# <ArrowStringArray>
# ['No', 'Yes', nan]
# Length: 3, dtype: str
#
# ApplicantIncome:
# [ 5849  4583  3000  2583  6000  5417  2333  3036  4006 12841  3200  2500
#   3073  1853  1299  4950  3596  3510  4887  2600  7660  5955  3365  3717
# ...

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
df = df.drop("Loan_ID", axis=1)
print(df.head())
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
#HANDLE CATEGORICAL MISSING VALUES
categorical_columns = [
    "Gender",
    "Married",
    "Dependents",
    "Self_Employed"
]

for col in categorical_columns:
    df[col] = df[col].fillna(df[col].mode()[0])
print("Categorical missing values handled.")
# Out:
# Categorical missing values handled.

# %%
#HANDLE NUMERICAL MISSING VALUES
numerical_columns = [
    "LoanAmount",
    "Loan_Amount_Term",
    "Credit_History"
]

for col in numerical_columns:
    df[col] = df[col].fillna(df[col].median())
print("Numerical missing values handled.")
# Out:
# Numerical missing values handled.

# %%
print("Missing Values After Preprocessing:")
print(df.isnull().sum())
# Out:
# Missing Values After Preprocessing:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# CONVERT DEPENDENTS
df["Dependents"] = df["Dependents"].replace("3+", "3")

# Convert Dependents to integer
df["Dependents"] = df["Dependents"].astype(int)

print("Unique Dependents values:")
print(df["Dependents"].unique())
# Out:
# Unique Dependents values:
# [0 1 2 3]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Loan Status distribution

# %%
print(df["Loan_Status"].value_counts())
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="Loan_Status")

plt.title("Loan Status Distribution")
plt.xlabel("Loan Status")
plt.ylabel("Number of Applicants")

plt.show()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %% [markdown]
# # Gender Distribution

# %%
print("Gender Counts:")
print(df["Gender"].value_counts())
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="Gender")

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Applicants")

plt.show()
# Out:
# Gender Counts:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %% [markdown]
# # Credit History vs Loan Status

# %%
print("Credit History vs Loan Status:")
print(pd.crosstab(df["Credit_History"], df["Loan_Status"]))
plt.figure(figsize=(7, 4))

sns.countplot(
    data=df,
    x="Credit_History",
    hue="Loan_Status"
)

plt.title("Credit History vs Loan Status")
plt.xlabel("Credit History")
plt.ylabel("Number of Applicants")

plt.show()
# Out:
# Credit History vs Loan Status:
# Loan_Status      N    Y
# Credit_History
# 0.0             82    7
# 1.0             97  378

# %% [markdown]
# # Education vs Loan Status

# %%
print("Education vs Loan Status:")
print(pd.crosstab(df["Education"], df["Loan_Status"]))
plt.figure(figsize=(7, 4))

sns.countplot(
    data=df,
    x="Education",
    hue="Loan_Status"
)

plt.title("Education vs Loan Status")
plt.xlabel("Education")
plt.ylabel("Number of Applicants")

plt.show()
# Out:
# Education vs Loan Status:
# Loan_Status     N    Y
# Education
# Graduate      140  340
# Not Graduate   52   82

# %% [markdown]
# # Property Area vs Loan Status

# %%
print("Property Area vs Loan Status:")
print(pd.crosstab(df["Property_Area"], df["Loan_Status"]))
plt.figure(figsize=(7, 4))

sns.countplot(
    data=df,
    x="Property_Area",
    hue="Loan_Status"
)

plt.title("Property Area vs Loan Status")
plt.xlabel("Property Area")
plt.ylabel("Number of Applicants")

plt.show()
# Out:
# Property Area vs Loan Status:
# Loan_Status     N    Y
# Property_Area
# Rural          69  110
# Semiurban      54  179
# Urban          69  133

# %% [markdown]
# # Applicant Income Distribution

# %%
print("Applicant Income Statistics:")
print(df["ApplicantIncome"].describe())
plt.figure(figsize=(8, 4))

sns.histplot(
    data=df,
    x="ApplicantIncome",
    kde=True
)

plt.title("Applicant Income Distribution")
plt.xlabel("Applicant Income")
plt.ylabel("Frequency")

plt.show()
# Out:
# Applicant Income Statistics:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# # Loan Amount Distribution

# %%
print("Loan Amount Statistics:")
print(df["LoanAmount"].describe())
plt.figure(figsize=(8, 4))

sns.histplot(
    data=df,
    x="LoanAmount",
    kde=True
)

plt.title("Loan Amount Distribution")
plt.xlabel("Loan Amount")
plt.ylabel("Frequency")

plt.show()
# Out:
# Loan Amount Statistics:
# count    592.000000
# mean     146.412162
# std       85.587325
# min        9.000000
# 25%      100.000000
# 50%      128.000000
# 75%      168.000000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %% [markdown]
# # Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])

# Calculate correlation
correlation = numeric_df.corr()

# Display correlation values
print("Correlation Matrix:")
print(correlation)

# Plot heatmap
plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()
# Out:
# Correlation Matrix:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %% [markdown]
# # Data Preprocessing

# %%
# LABEL ENCODING
from sklearn.preprocessing import LabelEncoder

# Create LabelEncoder
le = LabelEncoder()

categorical_columns = [
    "Gender",
    "Married",
    "Education",
    "Self_Employed",
    "Property_Area",
    "Loan_Status"
]

# Encode categorical columns
for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

print("Categorical encoding completed!")
print(df.head())
# Out:
# Categorical encoding completed!
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# ...

# %%
# CHECK DATA TYPES
print("Data Types After Encoding:")
print(df.dtypes)
# Out:
# Data Types After Encoding:
# Gender                 int64
# Married                int64
# Dependents             int64
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# Loan_Status            int64
# dtype: object

# %%
#Feature Engineering

df["TotalIncome"] = (
    df["ApplicantIncome"] +
    df["CoapplicantIncome"]
)

print("TotalIncome created successfully!")

print(
    df[
        ["ApplicantIncome",
         "CoapplicantIncome",
         "TotalIncome"]
    ].head()
)
# Out:
# TotalIncome created successfully!
#    ApplicantIncome  CoapplicantIncome  TotalIncome
# 0             5849                0.0       5849.0
# 1             4583             1508.0       6091.0
# 2             3000                0.0       3000.0
# 3             2583             2358.0       4941.0
# 4             6000                0.0       6000.0

# %%
#SEPARATE FEATURES AND TARGET
X = df.drop("Loan_Status", axis=1)

y = df["Loan_Status"]

print("Features (X):")
print(X.head())

print("\nTarget (y):")
print(y.head())
# Out:
# Features (X):
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  TotalIncome
# 0              2       5849.0
# 1              0       6091.0
# ...

# %%
# training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (491, 12)
# Testing data: (123, 12)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler

# Create scaler
scaler = StandardScaler()

# Fit ONLY on training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform test data using the same scaler
X_test_scaled = scaler.transform(X_test)

print("Feature scaling completed successfully!")

print("Scaled Training Data Shape:", X_train_scaled.shape)
print("Scaled Testing Data Shape:", X_test_scaled.shape)
# Out:
# Feature scaling completed successfully!
# Scaled Training Data Shape: (491, 12)
# Scaled Testing Data Shape: (123, 12)

# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    mean_squared_error,
    r2_score,
    confusion_matrix
)
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
y_pred_linear = linear_model.predict(X_test)
y_pred_linear_class = (y_pred_linear >= 0.5).astype(int)
linear_accuracy = accuracy_score(
    y_test,
    y_pred_linear_class
)

linear_precision = precision_score(
    y_test,
    y_pred_linear_class,
    zero_division=0
)

linear_recall = recall_score(
    y_test,
    y_pred_linear_class,
    zero_division=0
)

linear_f1 = f1_score(
    y_test,
    y_pred_linear_class,
    zero_division=0
)

linear_mse = mean_squared_error(
    y_test,
    y_pred_linear
)

linear_r2 = r2_score(
    y_test,
    y_pred_linear
)

print("LINEAR REGRESSION RESULTS")
print("=========================")

print("Accuracy :", round(linear_accuracy, 4))
print("Precision:", round(linear_precision, 4))
print("Recall   :", round(linear_recall, 4))
print("F1 Score :", round(linear_f1, 4))
print("MSE      :", round(linear_mse, 4))
print("R2 Score :", round(linear_r2, 4))


# Confusion Matrix
cm_linear = confusion_matrix(
    y_test,
    y_pred_linear_class
)

print("\nConfusion Matrix:")
print(cm_linear)

plt.figure(figsize=(8, 5))

plt.scatter(
    range(len(y_test)),
    y_test,
    label="Actual",
    color="blue",
    marker="o"
)

plt.scatter(
    range(len(y_pred_linear_class)),
    y_pred_linear_class,
    label="Predicted",
    color="red",
    marker="x"
)

plt.title("Linear Regression - Actual vs Predicted")
plt.xlabel("Applicant Record Number")
plt.ylabel("Loan Approval Status")

plt.yticks(
    [0, 1],
    ["Not Approved", "Approved"]
)

plt.legend()

plt.show()
# Out:
# LINEAR REGRESSION RESULTS
# ...
# Accuracy : 0.8618
# Precision: 0.84
# Recall   : 0.9882
# F1 Score : 0.9081
# MSE      : 0.1235
# R2 Score : 0.4215
#
# Confusion Matrix:
# [[22 16]
#  [ 1 84]]

# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")

logistic_model = LogisticRegression(
    max_iter=2000,
    random_state=42
)
# Parameters for tuning
param_grid = {
    "C": [0.01, 0.1, 1, 10, 100],
    "solver": ["liblinear", "lbfgs"]
}

# Find the best model internally
grid_logistic = GridSearchCV(
    estimator=logistic_model,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy"
)

grid_logistic.fit(
    X_train_scaled,
    y_train
)
# Use the best model
logistic_model = grid_logistic.best_estimator_
# Make predictions
y_pred_logistic = logistic_model.predict(
    X_test_scaled
)
# Evaluation metrics
logistic_accuracy = accuracy_score(
    y_test,
    y_pred_logistic
)

logistic_precision = precision_score(
    y_test,
    y_pred_logistic,
    zero_division=0
)

logistic_recall = recall_score(
    y_test,
    y_pred_logistic,
    zero_division=0
)

logistic_f1 = f1_score(
    y_test,
    y_pred_logistic,
    zero_division=0
)
# Display results
print("LOGISTIC REGRESSION RESULTS")
print("===========================")

print("Accuracy :", round(logistic_accuracy, 4))
print("Precision:", round(logistic_precision, 4))
print("Recall   :", round(logistic_recall, 4))
print("F1 Score :", round(logistic_f1, 4))


# Confusion Matrix
cm_logistic = confusion_matrix(
    y_test,
    y_pred_logistic
)

print("\nConfusion Matrix:")
print(cm_logistic)
plt.figure(figsize=(6, 5))

plt.imshow(cm_logistic, interpolation="nearest")

plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")

plt.colorbar()

plt.xticks([0, 1], ["Not Approved", "Approved"])
plt.yticks([0, 1], ["Not Approved", "Approved"])

for i in range(cm_logistic.shape[0]):
    for j in range(cm_logistic.shape[1]):
        plt.text(
            j,
            i,
            cm_logistic[i, j],
            ha="center",
            va="center"
        )

plt.tight_layout()
plt.show()
# Out:
# LOGISTIC REGRESSION RESULTS
# ...
# Accuracy : 0.8537
# Precision: 0.8317
# Recall   : 0.9882
# F1 Score : 0.9032
#
# Confusion Matrix:
# [[21 17]
#  [ 1 84]]

# %% [markdown]
# # K-Nearest Neighbors (KNN)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
# Create model
knn_model = KNeighborsClassifier()

# Parameters for tuning
param_grid = {
    "n_neighbors": range(3, 21, 2),
    "weights": ["uniform", "distance"],
    "metric": ["euclidean", "manhattan"]
}
# Find the best model internally
grid_knn = GridSearchCV(
    estimator=knn_model,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy"
)

grid_knn.fit(
    X_train_scaled,
    y_train
)
# Use the best model
knn_model = grid_knn.best_estimator_

# Make predictions
y_pred_knn = knn_model.predict(
    X_test_scaled
)
# Evaluation metrics
knn_accuracy = accuracy_score(
    y_test,
    y_pred_knn
)

knn_precision = precision_score(
    y_test,
    y_pred_knn,
    zero_division=0
)

knn_recall = recall_score(
    y_test,
    y_pred_knn,
    zero_division=0
)

knn_f1 = f1_score(
    y_test,
    y_pred_knn,
    zero_division=0
)
# Display results
print("K-NEAREST NEIGHBORS (KNN) RESULTS")
print("=================================")

print("Accuracy :", round(knn_accuracy, 4))
print("Precision:", round(knn_precision, 4))
print("Recall   :", round(knn_recall, 4))
print("F1 Score :", round(knn_f1, 4))

# Confusion Matrix
cm_knn = confusion_matrix(
    y_test,
    y_pred_knn
)

print("\nConfusion Matrix:")
print(cm_knn)
plt.figure(figsize=(6, 5))

plt.imshow(cm_knn, interpolation="nearest")

plt.title("K-Nearest Neighbors Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")

plt.colorbar()

plt.xticks([0, 1], ["Not Approved", "Approved"])
plt.yticks([0, 1], ["Not Approved", "Approved"])

for i in range(cm_knn.shape[0]):
    for j in range(cm_knn.shape[1]):
        plt.text(
            j,
            i,
            cm_knn[i, j],
            ha="center",
            va="center"
        )

plt.tight_layout()
plt.show()
# Out:
# K-NEAREST NEIGHBORS (KNN) RESULTS
# ...
# Accuracy : 0.8455
# Precision: 0.8235
# Recall   : 0.9882
# F1 Score : 0.8984
#
# Confusion Matrix:
# [[20 18]
#  [ 1 84]]

# %% [markdown]
# # DECISION TREE CLASSIFICATION

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import plot_tree
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
# Create model
tree_model = DecisionTreeClassifier(
    random_state=42
)

# Parameters for tuning
param_grid = {
    "criterion": ["gini", "entropy"],
    "max_depth": [3, 4, 5, 6, 8, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

# Find the best model internally
grid_tree = GridSearchCV(
    estimator=tree_model,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy"
)

grid_tree.fit(
    X_train,
    y_train
)

# Use the best model
tree_model = grid_tree.best_estimator_

# Make predictions
y_pred_tree = tree_model.predict(
    X_test
)

# Evaluation metrics
tree_accuracy = accuracy_score(
    y_test,
    y_pred_tree
)

tree_precision = precision_score(
    y_test,
    y_pred_tree,
    zero_division=0
)

tree_recall = recall_score(
    y_test,
    y_pred_tree,
    zero_division=0
)

tree_f1 = f1_score(
    y_test,
    y_pred_tree,
    zero_division=0
)

# Display results
print("DECISION TREE RESULTS")
print("=====================")

print("Accuracy :", round(tree_accuracy, 4))
print("Precision:", round(tree_precision, 4))
print("Recall   :", round(tree_recall, 4))
print("F1 Score :", round(tree_f1, 4))


# Confusion Matrix
cm_tree = confusion_matrix(
    y_test,
    y_pred_tree
)

print("\nConfusion Matrix:")
print(cm_tree)
plt.figure(figsize=(6, 5))

plt.imshow(cm_tree, interpolation="nearest")

plt.title("Decision Tree - Loan Status Confusion Matrix")

plt.xlabel("Predicted Loan Status")
plt.ylabel("Actual Loan Status")

plt.colorbar()

plt.xticks(
    [0, 1],
    ["Not Approved", "Approved"]
)

plt.yticks(
    [0, 1],
    ["Not Approved", "Approved"]
)

for i in range(cm_tree.shape[0]):
    for j in range(cm_tree.shape[1]):
        plt.text(
            j,
            i,
            cm_tree[i, j],
            ha="center",
            va="center"
        )

plt.tight_layout()
plt.show()
plt.figure(figsize=(20, 10))

plot_tree(
    tree_model,
    feature_names=X_train.columns,
    class_names=["Not Approved", "Approved"],
    filled=True,
    rounded=True,
    fontsize=9
)

plt.title("Decision Tree - Loan Approval Prediction")

plt.show()
# Out:
# DECISION TREE RESULTS
# ...
# Accuracy : 0.8537
# Precision: 0.8454
# Recall   : 0.9647
# F1 Score : 0.9011
#
# Confusion Matrix:
# [[23 15]
#  [ 3 82]]

# %% [markdown]
# # Model Comparison

# %%
import pandas as pd

final_results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Logistic Regression",
        "KNN",
        "Decision Tree"
    ],

    "Accuracy": [
        linear_accuracy,
        logistic_accuracy,
        knn_accuracy,
        tree_accuracy
    ],

    "Precision": [
        linear_precision,
        logistic_precision,
        knn_precision,
        tree_precision
    ],

    "Recall": [
        linear_recall,
        logistic_recall,
        knn_recall,
        tree_recall
    ],

    "F1 Score": [
        linear_f1,
        logistic_f1,
        knn_f1,
        tree_f1
    ]
})

# Round the values for easy reading
final_results = final_results.round(4)

# Display final comparison
print("FINAL MODEL COMPARISON")
print("======================")

print(final_results.to_string(index=False))
# Out:
# FINAL MODEL COMPARISON
# ...
#               Model  Accuracy  Precision  Recall  F1 Score
#   Linear Regression    0.8618     0.8400  0.9882    0.9081
# Logistic Regression    0.8537     0.8317  0.9882    0.9032
#                 KNN    0.8455     0.8235  0.9882    0.8984
#       Decision Tree    0.8537     0.8454  0.9647    0.9011

# %%
# BEST-PERFORMING MODEL

# Find the model with the highest F1 Score
best_model = final_results.loc[
    final_results["F1 Score"].idxmax(),
    "Model"
]

best_f1_score = final_results["F1 Score"].max()
print("BEST-PERFORMING MODEL")
print("=====================")

print("Model    :", best_model)
print("F1 Score :", best_f1_score)

best_model_result = final_results[
    final_results["Model"] == best_model
]

print("\nPerformance of Best Model:")
print(best_model_result.to_string(index=False))
# Out:
# BEST-PERFORMING MODEL
# ...
# Model    : Linear Regression
# F1 Score : 0.9081
#
# Performance of Best Model:
#             Model  Accuracy  Precision  Recall  F1 Score
# Linear Regression    0.8618       0.84  0.9882    0.9081

# %%
# CREDIT HISTORY VS LOAN STATUS
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
credit_history_insight = pd.crosstab(
    df["Credit_History"],
    df["Loan_Status"]
)

print("Credit History vs Loan Status")
print("=============================")

print(credit_history_insight)
# Out:
# Credit History vs Loan Status
# ...
# Loan_Status      N    Y
# Credit_History
# 0.0             82    7
# 1.0             97  378

# %%
# EDUCATION VS LOAN STATUS
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
education_insight = pd.crosstab(
    df["Education"],
    df["Loan_Status"]
)

print("Education vs Loan Status")
print("=========================")

print(education_insight)
# Out:
# Education vs Loan Status
# ...
# Loan_Status     N    Y
# Education
# Graduate      140  340
# Not Graduate   52   82

# %%
# STEP 19.3: PROPERTY AREA VS LOAN STATUS
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")
property_insight = pd.crosstab(
    df["Property_Area"],
    df["Loan_Status"]
)

print("Property Area vs Loan Status")
print("============================")

print(property_insight)
# Out:
# Property Area vs Loan Status
# ...
# Loan_Status     N    Y
# Property_Area
# Rural          69  110
# Semiurban      54  179
# Urban          69  133

# %%
# APPLICANT INCOME VS LOAN STATUS
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")

income_insight = df.groupby(
    "Loan_Status"
)["ApplicantIncome"].mean()

print("Average Applicant Income by Loan Status")
print("========================================")

print(income_insight)
# Out:
# Average Applicant Income by Loan Status
# ...
# Loan_Status
# N    5446.078125
# Y    5384.068720
# Name: ApplicantIncome, dtype: float64

# %%
# LOAN AMOUNT VS LOAN STATUS
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Desktop\ML\datasets\training.csv")

loan_amount_insight = df.groupby(
    "Loan_Status"
)["LoanAmount"].mean()

print("Average Loan Amount by Loan Status")
print("==================================")

print(loan_amount_insight)
# Out:
# Average Loan Amount by Loan Status
# ...
# Loan_Status
# N    151.220994
# Y    144.294404
# Name: LoanAmount, dtype: float64

# %%
# BUSINESS INSIGHTS SUMMARY

print("BUSINESS INSIGHTS")
print("=================")

print("1. Credit history is an important factor in loan approval.")
print("2. Loan approval patterns can differ across property areas.")
print("3. Applicant income can help assess the financial profile of applicants.")
print("4. Loan amount can influence the overall loan assessment.")
print("5. Machine learning can help automate and support loan approval decisions.")
# Out:
# BUSINESS INSIGHTS
# ...
# 1. Credit history is an important factor in loan approval.
# 2. Loan approval patterns can differ across property areas.
# 3. Applicant income can help assess the financial profile of applicants.
# 4. Loan amount can influence the overall loan assessment.
# 5. Machine learning can help automate and support loan approval decisions.
